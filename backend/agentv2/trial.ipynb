# %%
import pandas as pd
df = pd.read_csv('/Users/justinsurono/Documents/0projects/dashagent/agentv2/document/rawdata/OutletArticleTransaction (1).csv', skiprows=2)
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5542 entries, 0 to 5541
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            5306 non-null   object
#  1   Table Number    5306 non-null   float64
#  2   Bill Number     5542 non-null   object
#  3   Article Number  5306 non-null   float64
#  4   Description     5542 non-null   object
#  5   Outlet          5306 non-null   object
#  6   Quantity        5542 non-null   int64
#  7   Amount          5542 non-null   object
#  8   Time            5306 non-null   object
#  9   Posting ID      5306 non-null   float64
#  10  Guest Name      5289 non-null   object
#  11  Order Taker     0 non-null      float64
#  12  F/O Article     5306 non-null   object
#  13  Unnamed: 13     0 non-null      float64
# dtypes: float64(5), int64(1), object(8)
# memory usage: 606.3+ KB
#           Date  Table Number Bill Number  Article Number  \
# 0     01/01/25          71.0       15350             1.0
# 1     01/01/25          81.0       15351             1.0
# 2     01/01/25          82.0       15355             1.0
# 3     01/01/25          73.0       15357             1.0
# 4     01/01/25          71.0       15358             1.0
# ...        ...           ...         ...             ...
# 5537  02/01/25           1.0          75             5.0
# 5538  03/01/25           1.0          76             5.0
# 5539  21/01/25           1.0          77             5.0
# 5540       NaN           NaN                         NaN
# 5541       NaN           NaN                         NaN
#
#                  Description            Outlet  Quantity             Amount  \
# 0     ADDITIONAL BREAKFAST    Restaurant & Bar         1         125,000.00
# 1     ADDITIONAL BREAKFAST    Restaurant & Bar         1         125,000.00
# 2     ADDITIONAL BREAKFAST    Restaurant & Bar         1         125,000.00
# 3     ADDITIONAL BREAKFAST    Restaurant & Bar         1         125,000.00
# 4     ADDITIONAL BREAKFAST    Restaurant & Bar         1         125,000.00
# ...                      ...               ...       ...                ...
# 5537                 LUNCH             Banquet        14       2,800,000.00
# 5538                 LUNCH             Banquet        14       2,800,000.00
# 5539                 LUNCH             Banquet        14       2,800,000.00
# 5540              T O T A L                NaN        56      11,200,000.00
# 5541            GRAND TOTAL                NaN      6454      17,241,000.00
#
#           Time  Posting ID                        Guest Name  Order Taker  \
# 0     07:13:02        27.0                              8B15          NaN
# 1     08:05:02        27.0                              6B01          NaN
# 2     14:02:17        27.0                            17A05L          NaN
# 3     14:02:48        27.0                            18A05L          NaN
# 4     14:06:09        27.0                              8A07          NaN
# ...        ...         ...                               ...          ...
# 5537  15:21:06        27.0  PT CREATIVE TALENTA MANAGMENT ,           NaN
# 5538  15:38:04        27.0  PT CREATIVE TALENTA MANAGMENT ,           NaN
# 5539  13:15:32        27.0                      FIRMAN,   MR          NaN
# 5540       NaN         NaN                               NaN          NaN
# 5541       NaN         NaN                               NaN          NaN
#
#                        F/O Article  Unnamed: 13
# 0     Additional B'fast RESTAURANT          NaN
# 1     Additional B'fast RESTAURANT          NaN
# 2     Additional B'fast RESTAURANT          NaN
# 3     Additional B'fast RESTAURANT          NaN
# 4     Additional B'fast RESTAURANT          NaN
# ...                            ...          ...
# 5537                  Food BANQUET          NaN
# 5538                  Food BANQUET          NaN
# 5539                  Food BANQUET          NaN
# 5540                           NaN          NaN
# 5541                           NaN          NaN
#
# [5542 rows x 14 columns]

# %%
dfdropna = df.dropna(subset=['Date'])
dfdropna['Date'] = pd.to_datetime(dfdropna['Date'])
dfdropna.info()
dfdropna
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5306 entries, 0 to 5539
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            5306 non-null   datetime64[ns]
#  1   Table Number    5306 non-null   float64
#  2   Bill Number     5306 non-null   object
#  3   Article Number  5306 non-null   float64
#  4   Description     5306 non-null   object
#  5   Outlet          5306 non-null   object
#  6   Quantity        5306 non-null   int64
#  7   Amount          5306 non-null   object
#  8   Time            5306 non-null   object
#  9   Posting ID      5306 non-null   float64
#  10  Guest Name      5289 non-null   object
#  11  Order Taker     0 non-null      float64
#  12  F/O Article     5306 non-null   object
#  13  Unnamed: 13     0 non-null      float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(7)
# memory usage: 621.8+ KB
# /var/folders/02/mkplvxgn76d95v80kwz7_zzh0000gn/T/ipykernel_18867/1787687877.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dfdropna['Date'] = pd.to_datetime(dfdropna['Date'])
# /var/folders/02/mkplvxgn76d95v80kwz7_zzh0000gn/T/ipykernel_18867/1787687877.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfdropna['Date'] = pd.to_datetime(dfdropna['Date'])
#            Date  Table Number Bill Number  Article Number  \
# 0    2025-01-01          71.0       15350             1.0
# 1    2025-01-01          81.0       15351             1.0
# 2    2025-01-01          82.0       15355             1.0
# 3    2025-01-01          73.0       15357             1.0
# 4    2025-01-01          71.0       15358             1.0
# ...         ...           ...         ...             ...
# 5534 2025-01-21           1.0          77             4.0
# 5536 2025-01-01           1.0          74             5.0
# 5537 2025-02-01           1.0          75             5.0
# 5538 2025-03-01           1.0          76             5.0
# 5539 2025-01-21           1.0          77             5.0
#
#                  Description            Outlet  Quantity             Amount  \
# 0     ADDITIONAL BREAKFAST    Restaurant & Bar         1         125,000.00
# 1     ADDITIONAL BREAKFAST    Restaurant & Bar         1         125,000.00
# 2     ADDITIONAL BREAKFAST    Restaurant & Bar         1         125,000.00
# 3     ADDITIONAL BREAKFAST    Restaurant & Bar         1         125,000.00
# 4     ADDITIONAL BREAKFAST    Restaurant & Bar         1         125,000.00
# ...                      ...               ...       ...                ...
# 5534          COFFEE BREAK             Banquet        14         700,000.00
# 5536                 LUNCH             Banquet        14       2,800,000.00
# 5537                 LUNCH             Banquet        14       2,800,000.00
# 5538                 LUNCH             Banquet        14       2,800,000.00
# 5539                 LUNCH             Banquet        14       2,800,000.00
#
#           Time  Posting ID                        Guest Name  Order Taker  \
# 0     07:13:02        27.0                              8B15          NaN
# 1     08:05:02        27.0                              6B01          NaN
# 2     14:02:17        27.0                            17A05L          NaN
# 3     14:02:48        27.0                            18A05L          NaN
# 4     14:06:09        27.0                              8A07          NaN
# ...        ...         ...                               ...          ...
# 5534  13:15:32        27.0                      FIRMAN,   MR          NaN
# 5536  14:22:39        27.0  PT CREATIVE TALENTA MANAGMENT ,           NaN
# 5537  15:21:06        27.0  PT CREATIVE TALENTA MANAGMENT ,           NaN
# 5538  15:38:04        27.0  PT CREATIVE TALENTA MANAGMENT ,           NaN
# 5539  13:15:32        27.0                      FIRMAN,   MR          NaN
#
#                        F/O Article  Unnamed: 13
# 0     Additional B'fast RESTAURANT          NaN
# 1     Additional B'fast RESTAURANT          NaN
# 2     Additional B'fast RESTAURANT          NaN
# 3     Additional B'fast RESTAURANT          NaN
# 4     Additional B'fast RESTAURANT          NaN
# ...                            ...          ...
# 5534                  Food BANQUET          NaN
# 5536                  Food BANQUET          NaN
# 5537                  Food BANQUET          NaN
# 5538                  Food BANQUET          NaN
# 5539                  Food BANQUET          NaN
#
# [5306 rows x 14 columns]

# %%
# sort dfdropna by col 'Bill Number'
dfsorted = dfdropna.sort_values(by='Bill Number')
dfsorted.info()
dfsorted
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5306 entries, 0 to 5539
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            5306 non-null   datetime64[ns]
#  1   Table Number    5306 non-null   float64
#  2   Bill Number     5306 non-null   object
#  3   Article Number  5306 non-null   float64
#  4   Description     5306 non-null   object
#  5   Outlet          5306 non-null   object
#  6   Quantity        5306 non-null   int64
#  7   Amount          5306 non-null   object
#  8   Time            5306 non-null   object
#  9   Posting ID      5306 non-null   float64
#  10  Guest Name      5289 non-null   object
#  11  Order Taker     0 non-null      float64
#  12  F/O Article     5306 non-null   object
#  13  Unnamed: 13     0 non-null      float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(7)
# memory usage: 621.8+ KB
#            Date  Table Number Bill Number  Article Number  \
# 0    2025-01-01          71.0       15350             1.0
# 4433 2025-01-01          71.0       15350          9900.0
# 127  2025-01-01          71.0       15350             3.0
# 1    2025-01-01          81.0       15351             1.0
# 4434 2025-01-01          81.0       15351          9900.0
# ...         ...           ...         ...             ...
# 5538 2025-03-01           1.0          76             5.0
# 5531 2025-03-01           1.0          76             4.0
# 5533 2025-01-21           1.0          77             4.0
# 5534 2025-01-21           1.0          77             4.0
# 5539 2025-01-21           1.0          77             5.0
#
#                     Description            Outlet  Quantity  \
# 0        ADDITIONAL BREAKFAST    Restaurant & Bar         1
# 4433                  Cash Rp    Restaurant & Bar         1
# 127   ADD BREAKFAST CHILD 50%    Restaurant & Bar         1
# 1        ADDITIONAL BREAKFAST    Restaurant & Bar         1
# 4434                  Cash Rp    Restaurant & Bar         1
# ...                         ...               ...       ...
# 5538                    LUNCH             Banquet        14
# 5531             COFFEE BREAK             Banquet        14
# 5533             COFFEE BREAK             Banquet        14
# 5534             COFFEE BREAK             Banquet        14
# 5539                    LUNCH             Banquet        14
#
#                  Amount      Time  Posting ID  \
# 0            125,000.00  07:13:02        27.0
# 4433        -187,500.00  14:03:09        27.0
# 127           62,500.00  07:13:03        27.0
# 1            125,000.00  08:05:02        27.0
# 4434        -125,000.00  14:03:18        27.0
# ...                 ...       ...         ...
# 5538       2,800,000.00  15:38:04        27.0
# 5531         700,000.00  15:38:04        27.0
# 5533         700,000.00  13:15:32        27.0
# 5534         700,000.00  13:15:32        27.0
# 5539       2,800,000.00  13:15:32        27.0
#
#                             Guest Name  Order Taker  \
# 0                                 8B15          NaN
# 4433                              8B15          NaN
# 127                               8B15          NaN
# 1                                 6B01          NaN
# 4434                              6B01          NaN
# ...                                ...          ...
# 5538  PT CREATIVE TALENTA MANAGMENT ,           NaN
# 5531  PT CREATIVE TALENTA MANAGMENT ,           NaN
# 5533                      FIRMAN,   MR          NaN
# 5534                      FIRMAN,   MR          NaN
# 5539                      FIRMAN,   MR          NaN
#
#                        F/O Article  Unnamed: 13
# 0     Additional B'fast RESTAURANT          NaN
# 4433                   Cash Outlet          NaN
# 127   Additional B'fast RESTAURANT          NaN
# 1     Additional B'fast RESTAURANT          NaN
# 4434                   Cash Outlet          NaN
# ...                            ...          ...
# 5538                  Food BANQUET          NaN
# 5531                  Food BANQUET          NaN
# 5533                  Food BANQUET          NaN
# 5534                  Food BANQUET          NaN
# 5539                  Food BANQUET          NaN
#
# [5306 rows x 14 columns]

# %%
# export as csv
dfsorted.to_csv('dfsorted.csv', index=False)

# %%
from openai import get_all_tools

all_tools = get_all_tools()

tools_description = "\n".join([f"- {t.name}: {t.description}" for t in all_tools])

print(tools_description)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from openai import get_all_tools
#       3 all_tools = get_all_tools()
#       5 tools_description = "\n".join([f"- {t.name}: {t.description}" for t in all_tools])
#
# ImportError: cannot import name 'get_all_tools' from 'openai' (/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/openai/__init__.py)

# %%
import asyncio
from agents import Runner
from agents_team.prompt_agent import prompt_agent

async def test():
    result = Runner.run_streamed(prompt_agent, input='data tamu hotel')
    
    # Stream events to completion
    async for event in result.stream_events():
        pass
    
    print('Final output:', result.final_output)
    if result.final_output:
        print('Thoughts:', result.final_output.thoughts)
        print('Queries:')
        for i, q in enumerate(result.final_output.queries, 1):
            print(f'  {i}. {q}')

asyncio.run(test())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 import asyncio
# ----> 2 from agents import Runner
#       3 from agents_team.prompt_agent import prompt_agent
#       5 async def test():
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/__init__.py:7
#       3 from typing import Literal
#       5 from openai import AsyncOpenAI
# ----> 7 from . import _config
#       8 from .agent import (
#       9     Agent,
#      10     AgentBase,
#    (...)     13     ToolsToFinalOutputResult,
#      14 )
#      15 from .agent_output import AgentOutputSchema, AgentOutputSchemaBase
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/_config.py:4
#       1 from openai import AsyncOpenAI
#       2 from typing_extensions import Literal
# ----> 4 from .models import _openai_shared
#       5 from .tracing import set_tracing_export_api_key
#       8 def set_default_openai_key(key: str, use_for_tracing: bool) -> None:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/models/__init__.py:1
# ----> 1 from .default_models import (
#       2     get_default_model,
#       3     get_default_model_settings,
#       4     gpt_5_reasoning_settings_required,
#       5     is_gpt_5_default,
#       6 )
#       8 __all__ = [
#       9     "get_default_model",
#      10     "get_default_model_settings",
#      11     "gpt_5_reasoning_settings_required",
#      12     "is_gpt_5_default",
#      13 ]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/models/default_models.py:7
#       3 from typing import Optional
#       5 from openai.types.shared.reasoning import Reasoning
# ----> 7 from agents.model_settings import ModelSettings
#       9 OPENAI_DEFAULT_MODEL_ENV_VARIABLE_NAME = "OPENAI_DEFAULT_MODEL"
#      11 # discourage directly accessing this constant
#      12 # use the get_default_model and get_default_model_settings() functions instead
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/model_settings.py:12
#      10 from openai.types.responses import ResponseIncludable
#      11 from openai.types.shared import Reasoning
# ---> 12 from pydantic import BaseModel, GetCoreSchemaHandler
#      13 from pydantic.dataclasses import dataclass
#      14 from pydantic_core import core_schema
#
# ImportError: cannot import name 'GetCoreSchemaHandler' from 'pydantic' (/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pydantic/__init__.cpython-313-darwin.so)

# %%
import asyncio
from agents import Runner
from agents_team.analyst_agent import analyst_agent
from agents.extensions.memory.sqlalchemy_session import SQLAlchemySession
from sqlalchemy.ext.asyncio import create_async_engine
from dotenv import load_dotenv
import os

load_dotenv()

DATABASE_URL = os.getenv("DATABASE_URL")

engine = create_async_engine(DATABASE_URL, pool_pre_ping=True)

# make session
session = SQLAlchemySession(
    session_id="testing",
    engine=engine,
    create_tables=True,
)


async def test():
    result = Runner.run_streamed(analyst_agent, input='data tamu hotel', session=session)
    
    # Stream events to completion
    async for event in result.stream_events():
        pass
    
    print('Final output:', result.final_output)

asyncio.run(test())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import asyncio
# ----> 2 from agents import Runner
#       3 from agents_team.analyst_agent import analyst_agent
#       4 from agents.extensions.memory.sqlalchemy_session import SQLAlchemySession
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/__init__.py:7
#       3 from typing import Literal
#       5 from openai import AsyncOpenAI
# ----> 7 from . import _config
#       8 from .agent import (
#       9     Agent,
#      10     AgentBase,
#    (...)     13     ToolsToFinalOutputResult,
#      14 )
#      15 from .agent_output import AgentOutputSchema, AgentOutputSchemaBase
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/_config.py:4
#       1 from openai import AsyncOpenAI
#       2 from typing_extensions import Literal
# ----> 4 from .models import _openai_shared
#       5 from .tracing import set_tracing_export_api_key
#       8 def set_default_openai_key(key: str, use_for_tracing: bool) -> None:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/models/__init__.py:1
# ----> 1 from .default_models import (
#       2     get_default_model,
#       3     get_default_model_settings,
#       4     gpt_5_reasoning_settings_required,
#       5     is_gpt_5_default,
#       6 )
#       8 __all__ = [
#       9     "get_default_model",
#      10     "get_default_model_settings",
#      11     "gpt_5_reasoning_settings_required",
#      12     "is_gpt_5_default",
#      13 ]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/models/default_models.py:7
#       3 from typing import Optional
#       5 from openai.types.shared.reasoning import Reasoning
# ----> 7 from agents.model_settings import ModelSettings
#       9 OPENAI_DEFAULT_MODEL_ENV_VARIABLE_NAME = "OPENAI_DEFAULT_MODEL"
#      11 # discourage directly accessing this constant
#      12 # use the get_default_model and get_default_model_settings() functions instead
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/model_settings.py:12
#      10 from openai.types.responses import ResponseIncludable
#      11 from openai.types.shared import Reasoning
# ---> 12 from pydantic import BaseModel, GetCoreSchemaHandler
#      13 from pydantic.dataclasses import dataclass
#      14 from pydantic_core import core_schema
#
# ImportError: cannot import name 'GetCoreSchemaHandler' from 'pydantic' (/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pydantic/__init__.cpython-313-darwin.so)

# %%
import asyncio
from agents import run_demo_loop

from agents_team.prompt_agent import prompt_agent

async def main() -> None:
    agent = prompt_agent
    await run_demo_loop(agent)

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 2
#       1 import asyncio
# ----> 2 from agents import run_demo_loop
#       4 from agents_team.prompt_agent import prompt_agent
#       6 async def main() -> None:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/__init__.py:7
#       3 from typing import Literal
#       5 from openai import AsyncOpenAI
# ----> 7 from . import _config
#       8 from .agent import (
#       9     Agent,
#      10     AgentBase,
#    (...)     13     ToolsToFinalOutputResult,
#      14 )
#      15 from .agent_output import AgentOutputSchema, AgentOutputSchemaBase
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/_config.py:4
#       1 from openai import AsyncOpenAI
#       2 from typing_extensions import Literal
# ----> 4 from .models import _openai_shared
#       5 from .tracing import set_tracing_export_api_key
#       8 def set_default_openai_key(key: str, use_for_tracing: bool) -> None:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/models/__init__.py:1
# ----> 1 from .default_models import (
#       2     get_default_model,
#       3     get_default_model_settings,
#       4     gpt_5_reasoning_settings_required,
#       5     is_gpt_5_default,
#       6 )
#       8 __all__ = [
#       9     "get_default_model",
#      10     "get_default_model_settings",
#      11     "gpt_5_reasoning_settings_required",
#      12     "is_gpt_5_default",
#      13 ]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/models/default_models.py:7
#       3 from typing import Optional
#       5 from openai.types.shared.reasoning import Reasoning
# ----> 7 from agents.model_settings import ModelSettings
#       9 OPENAI_DEFAULT_MODEL_ENV_VARIABLE_NAME = "OPENAI_DEFAULT_MODEL"
#      11 # discourage directly accessing this constant
#      12 # use the get_default_model and get_default_model_settings() functions instead
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/model_settings.py:12
#      10 from openai.types.responses import ResponseIncludable
#      11 from openai.types.shared import Reasoning
# ---> 12 from pydantic import BaseModel, GetCoreSchemaHandler
#      13 from pydantic.dataclasses import dataclass
#      14 from pydantic_core import core_schema
#
# ImportError: cannot import name 'GetCoreSchemaHandler' from 'pydantic' (/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pydantic/__init__.cpython-313-darwin.so)

# %%
from agents import Agent, run_demo_loop

def main() -> None:
    agent = Agent(name="Assistant", instructions="You are a helpful assistant.")
    run_demo_loop(agent)

# run main
main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from agents import Agent, run_demo_loop
#       3 def main() -> None:
#       4     agent = Agent(name="Assistant", instructions="You are a helpful assistant.")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/__init__.py:7
#       3 from typing import Literal
#       5 from openai import AsyncOpenAI
# ----> 7 from . import _config
#       8 from .agent import (
#       9     Agent,
#      10     AgentBase,
#    (...)     13     ToolsToFinalOutputResult,
#      14 )
#      15 from .agent_output import AgentOutputSchema, AgentOutputSchemaBase
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/_config.py:4
#       1 from openai import AsyncOpenAI
#       2 from typing_extensions import Literal
# ----> 4 from .models import _openai_shared
#       5 from .tracing import set_tracing_export_api_key
#       8 def set_default_openai_key(key: str, use_for_tracing: bool) -> None:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/models/__init__.py:1
# ----> 1 from .default_models import (
#       2     get_default_model,
#       3     get_default_model_settings,
#       4     gpt_5_reasoning_settings_required,
#       5     is_gpt_5_default,
#       6 )
#       8 __all__ = [
#       9     "get_default_model",
#      10     "get_default_model_settings",
#      11     "gpt_5_reasoning_settings_required",
#      12     "is_gpt_5_default",
#      13 ]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/models/default_models.py:7
#       3 from typing import Optional
#       5 from openai.types.shared.reasoning import Reasoning
# ----> 7 from agents.model_settings import ModelSettings
#       9 OPENAI_DEFAULT_MODEL_ENV_VARIABLE_NAME = "OPENAI_DEFAULT_MODEL"
#      11 # discourage directly accessing this constant
#      12 # use the get_default_model and get_default_model_settings() functions instead
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agents/model_settings.py:12
#      10 from openai.types.responses import ResponseIncludable
#      11 from openai.types.shared import Reasoning
# ---> 12 from pydantic import BaseModel, GetCoreSchemaHandler
#      13 from pydantic.dataclasses import dataclass
#      14 from pydantic_core import core_schema
#
# ImportError: cannot import name 'GetCoreSchemaHandler' from 'pydantic' (/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pydantic/__init__.cpython-313-darwin.so)
